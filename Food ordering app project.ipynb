# %%
import json
class Subway:
    def __init__(self):
        self.foods={}
        self.food_id=len(self.foods)+1
        self.personal_details={}
        self.login=len(self.personal_details)+1
        self.order=[]
        
# Admin Functionality:
    def food_items(self):
        self.name=input("Enter the food Name ")
        self.quantity=int(input("Enter food Quantity "))
        self.price=int(input("Enter food Price :Rs "))
        self.discount=int(input("Enter food Discount :% "))
        self.stock=int(input("Enter food Stock :kg "))
        self.item={"name":self.name,"quantity":self.quantity,"price":self.price,"discount":self.discount,"stock":self.stock}
        self.food_id=len(self.foods)+1
        self.foods[self.food_id]=self.item
        print(self.foods)
        with open("food_items.json","w")as f:
            json.dump(self.foods,f)
        print("Items added successfully")
        print("*******************************************************")
    def remove_food_items(self):
        del self.foods[int(input("Enter the food_id which you want to delete "))]
        print("remaining items are", self.foods)
        with open("food_items.json","w")as f:
            json.dump(self.foods,f)
        print("remaining items are", self.foods)
        print("****************************************************************")
    def edit_food_items(self):
        fd_id=int(input("Enter the food_id which you want to update "))
        for i in self.foods[fd_id]:
            self.foods[fd_id][i]=input(f"Enter the {i} that you want to update: ")
            print(self.foods)
        with open("food_items.json","w")as f:
            json.dump(self.foods,f)
        print("food_items updated successfully")
        print("******************************************************************")
            
    def view_food_items(self):
        print("list of all  food items menu ")
        for i in self.foods:
            print("food_id :",i,"******************")
            for j in self.foods[i]:
                print(j,":",self.foods[i][j])
                print("********************************************************************")

            
            
# User Functionality:
    def registration(self):
        self.full_name=input("Enter the full name ")
        self.phone_number=int(input("Enter the phone number "))
        self.email=input("Enter the email ")
        self.address=input("Enter the address ")
        self.password=input("enter the password ")
        self.register={"full_name":self.full_name,"phone_number":self.phone_number,"email":self.email,"address":self.address,"password":self.password}
        self.login=len(self.personal_details)+1
        self.personal_details[self.login]=self.register
        print(self.personal_details)
        if self.email=="priyankasharma.1178791@gmail.com":
                if self.password=="password":
                    print("you have successfully logged in ")
                else:
                    print("Incorrect details please fill correct details ")
        else:
             print("Incorrect credentials ")
        with open("registration.json","w")as f:
            json.dump(self.personal_details,f)
        print("your personal details added successfully")
        print("***********************************************************")
    def place_new_order(self):
        true=1
        while true:
            print("enter the order that you want to place \n1 TandooriChicken \n2 Vegan Burger \n3 Truffle cake")
            y=int(input("Enter your choice "))
        if y==1:
            self.order.append("TandooriChicken")
            print("Tandoori chicken is added")
            break
        if y==2:
            self.order.append("VeganBurger")
            print("vegan burger is added")
            break
        if y==3:
            self.order.append("TruffleCake")
            print("truffle cake is added")
            break
        else:
            print("please give currently available order ")
            print(self.personal_details)
            with open("registration.json","w")as f:
                json.dump(self.personal_details,f)
            print("********************************************")
    def order_history(self):
        for i in self.personal_details[place_new_order]:
            print(self.personal_details)
            with open("registration.json","w")as f:
                json.dump(self.personal_details,f)
            print("*********************************************")
    def update_details(self):
        login=int(input("Enter the login which you want to update "))
        for i in self.personal_details[login]:
            self.personal_details[login][i]=input(f"Enter the {i} that you want to update: ")
            print(self.personal_details)
            with open("registration.json","w")as f:
                json.dump(self.personal_details,f)
            print("***************************************")
        
        
        
   
s=Subway()
print("welcome to the Subway")
true=1
while true:
    print("Enter how you want to login as a \n1 Admin \n2 user \n3 Exit")
    x=int(input("enter your choice of login "))
    if x==1:
        print("welcome Admin")
        print("what you want to do ")
        print("1 food items")
        print("2 remove items")
        print("3 edit items")
        print("4 view items")
        break
s.food_items()                                                                                                                                    
print("***************************************************************")
s.remove_food_items()
print("***************************************************************************")
s.edit_food_items()
print("*************************************************************************")
s.view_food_items()
print("**************************************************************************")
   elif x==2:
        print("welcome user")
        print("what you want to do")
        print("1 registration")
        print("2 place order")
        print("3 order history")
        print("4 update details")
        break
s.registration()
print("***********************************************************")
s.place_new_order()
print("**************************************************************")
s.order_history()
print("**************************************************************")
s.update_details()
print("**************************************************************")
    elif x==3:
        print("Thankyou for coming")
        break
    else:
        print("please enter the correct choice ")
# Out:
#   Input In [4]
#     elif x==2:
#     ^
# IndentationError: unexpected indent
